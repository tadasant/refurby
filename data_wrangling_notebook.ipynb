# %%
import random

import pandas as pd
import numpy as np
import nltk
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report
from sklearn.externals import joblib
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /Users/adrianlievano/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ## Explore the input data

# %%
opportunity = {
    'industry': 'Internet',
    'min_years_experience': 3,
    'city': 'San Francisco',
    'highestLevelOfEducation': 'bachelor',
    'blurb': 'I need a software engineer that has experience in pytorch, python, aws, spark, and airflow. They should want to work for a startup that has less than 500 employees. We do not want new graduates.',
    'title': 'Seeking Software Engineer (Full-Time)'
}

# %%
industrys = ['Internet', 'Technology', 'Enterprise Software']
min_years_experiences = [1, 2, 3, 4, 5, 6, 7]
citys = ['San Francisco', 'New York City', 'Los Angeles']
highestLevelOfEducations = ['high_school', 'associate', 'bachelor', 'master', 'phd']
blurbs = ['I need a software engineer that has experience in pytorch, python, aws, spark, and airflow. They should want to work for a startup that has less than 500 employees. We do not want new graduates.',
          'We need a full stack machine learning engineer that knows REST APIs, flask, and tensorflow.',
          'Find me data scientist that knows SQL, tableu, excel, machine learning.', 
          'We just need a developer that has six or 7 years of experience']
titles = ['Software Engineer', 'Data Scientist', 'Machine Learning Engineer', 'Software Engineer (Machine Learning)']

df_test = pd.DataFrame()

num_opportunities = 5
rows = []

for i in range(num_opportunities):
    row_ele = {
    'industry': random.choice(industrys),
    'min_years_experience': random.choice(min_years_experiences),
    'city': random.choice(citys),
    'highestLevelOfEducation': random.choice(highestLevelOfEducations),
    'blurb': random.choice(blurbs),
    'title': random.choice(titles)
    }
    rows.append(row_ele)

# %% [markdown]
# ## Construct Dummy Table - Opportunity Submission Table
#
# #### This is a table with queries that a poster might use to find a candidate in their network

# %%
opportunities_df = pd.DataFrame(rows)
opportunities_df.head(10)
# Out:
#                                                blurb           city  \
# 0  We just need a developer that has six or 7 yea...  New York City
# 1  We just need a developer that has six or 7 yea...  San Francisco
# 2  Find me data scientist that knows SQL, tableu,...  New York City
# 3  We just need a developer that has six or 7 yea...  San Francisco
# 4  We just need a developer that has six or 7 yea...  New York City
#
#   highestLevelOfEducation             industry  min_years_experience  \
# 0                  master             Internet                     2
# 1                bachelor  Enterprise Software                     7
# 2                  master             Internet                     6
# 3               associate           Technology                     5
# 4                     phd  Enterprise Software                     5
#
#                                   title
# 0  Software Engineer (Machine Learning)
# 1             Machine Learning Engineer
# 2                     Software Engineer
# 3  Software Engineer (Machine Learning)
# 4                     Software Engineer

# %% [markdown]
# ## Construct Dummy Table - Candidate Table

# %% [markdown]
# Candidate dictionary
# {
#     id: int
#     email: 'str'
#     name: 'str'
#     location: list['city', 'state']
#     current_position: 'str',
#     years_of_experience: int
#     industry: 'str'
#     degree_connection: str
#     degree = str
# }

# %%
candidates_total = 10000
emails = []
names = []

for i in range(candidates_total):
    email = ('{}'+'xxxxxxx@gmail.com').format(i)
    emails.append(email)
    
for i in range(candidates_total):
    name = ('name + {}'.format(i))
    names.append(name)

ids = [i for i in range(candidates_total)]
emails = emails
names = names
citys = ['San Francisco', 'New York City', 'Los Angeles']
#state = ['California', 'New York', 'Florida']
current_positions = ['Software Engineer', 'Data Scientist', 'Machine Learning Engineer', 'Bioengineer']
industrys = ['Internet', 'Technology', 'Enterprise Software', 'Biotech']
years_of_experiences = [1, 2, 3, 4, 5, 6, 7]
linkedin_urls = ['https://www.linkedin.com/adrianlievano']
image_urls = ['https://www.linkedin.com/adrianlievano/profile_pic.png']
degrees = ['1st', '2nd']
highestLevelOfEducations = ['high_school', 'associate', 'bachelor', 'master', 'phd']

candidate_rows = []

for i in range(candidates_total):
    row_ele = {
    'id': random.choice(ids),
    'email': random.choice(emails),
    'name': random.choice(names),
    'phone_number': '786-515-4282',
    'city': random.choice(citys),
    #'location': random.choice(locations),
    'current_position': random.choice(current_positions),
    'industry': random.choice(industrys),
    'years_of_experience': random.choice(years_of_experiences),
    'degree': random.choice(degrees),
    'linkedin_url': random.choice(linkedin_urls),
    'image_url': random.choice(image_urls),
    'highestLevelOfEducation': random.choice(highestLevelOfEducations)
    }
    candidate_rows.append(row_ele)

# %%
can`didate_rows
# Out:
#   File "<ipython-input-6-80b8204725b9>", line 1
#     can`didate_rows
#        ^
# SyntaxError: invalid syntax

# %%
df_candidates = pd.DataFrame(candidate_rows)
df_candidates

# %% [markdown]
# ### Phase 1: Knowledge Based Heuristic ###

# %% [markdown]
# 1. Filter 1: Filter by location
# 2. Filter 2: Filter by >= years of experience
# 3. Filter 3: Filter subset by title embeddings
# 4. Filter 4: Filter by degrees
# 5. Filter 5: Filter by industry
# 6. Filter 6: Filter by blurb
#
# Create score column in candidate table that assigns reward for each applicable filter

# %%
opportunity_sample_request = dict(opportunities_df.iloc[0])
opportunity_sample_request #pandas series

opportunity_sample_request['industry']

# %%
opportunity_sample_request['city']

# %%
opportunity_sample_request['min_years_experience']

# %% [markdown]
# ## Filter based on location

# %% [markdown]
# df_candidates[(df_candidates['city'] == opportunity_sample_request['location'][0]) & (
#               df_candidates['state'] == opportunity_sample_request['location'][1])]

# %% [markdown]
# ## Filter based on current_position - (TBD)

# %% [markdown]
# opportunity_sample_request['current_position']

# %% [markdown]
# df_candidates[df_candidates['current_position'] == str(opportunity_sample_request['current_position'])].head()

# %% [markdown]
# ## Filter based on degree major

# %%
df_candidates = pd.DataFrame(candidate_rows)

# %%
df_candidates[df_candidates['highestLevelOfEducation'] == str(opportunity_sample_request['highestLevelOfEducation'])].head()
# Out:
#              city           current_position degree                  email  \
# 0   New York City  Machine Learning Engineer    2nd  6287xxxxxxx@gmail.com
# 2     Los Angeles             Data Scientist    1st  3503xxxxxxx@gmail.com
# 8     Los Angeles  Machine Learning Engineer    2nd    34xxxxxxx@gmail.com
# 14  New York City  Machine Learning Engineer    1st  4399xxxxxxx@gmail.com
# 17  New York City                Bioengineer    2nd  6853xxxxxxx@gmail.com
#
#    highestLevelOfEducation    id  \
# 0                 bachelor  2701
# 2                 bachelor  2834
# 8                 bachelor  5740
# 14                bachelor   991
# 17                bachelor    31
#
#                                             image_url             industry  \
# 0   https://www.linkedin.com/adrianlievano/profile...  Enterprise Software
# 2   https://www.linkedin.com/adrianlievano/profile...  Enterprise Software
# 8   https://www.linkedin.com/adrianlievano/profile...              Biotech
# 14  https://www.linkedin.com/adrianlievano/profile...             Internet
# 17  https://www.linkedin.com/adrianlievano/profile...             Internet
#
#                               linkedin_url         name  phone_number  \
# 0   https://www.linkedin.com/adrianlievano  name + 1163  786-515-4282
# 2   https://www.linkedin.com/adrianlievano  name + 4863  786-515-4282
# 8   https://www.linkedin.com/adrianlievano   name + 859  786-515-4282
# 14  https://www.linkedin.com/adrianlievano  name + 1149  786-515-4282
# 17  https://www.linkedin.com/adrianlievano  name + 4969  786-515-4282
#
#     years_of_experience
# 0                     6
# 2                     4
# 8                     3
# 14                    6
# 17                    1

# %% [markdown]
# ## Sort by degree connection

# %%
df_candidates.sort_values(by = 'degree', ascending = True).head()
# Out:
#                city           current_position degree                  email  \
# 4999  New York City             Data Scientist    1st  8493xxxxxxx@gmail.com
# 7956  New York City             Data Scientist    1st  2751xxxxxxx@gmail.com
# 4152    Los Angeles                Bioengineer    1st  7105xxxxxxx@gmail.com
# 4149  San Francisco  Machine Learning Engineer    1st  9723xxxxxxx@gmail.com
# 4147  San Francisco          Software Engineer    1st  4780xxxxxxx@gmail.com
#
#      highestLevelOfEducation    id  \
# 4999               associate   904
# 7956                  master  3739
# 4152                bachelor  6979
# 4149             high_school  8280
# 4147                bachelor  7187
#
#                                               image_url             industry  \
# 4999  https://www.linkedin.com/adrianlievano/profile...              Biotech
# 7956  https://www.linkedin.com/adrianlievano/profile...  Enterprise Software
# 4152  https://www.linkedin.com/adrianlievano/profile...           Technology
# 4149  https://www.linkedin.com/adrianlievano/profile...  Enterprise Software
# 4147  https://www.linkedin.com/adrianlievano/profile...              Biotech
#
#                                 linkedin_url         name  phone_number  \
# 4999  https://www.linkedin.com/adrianlievano  name + 4731  786-515-4282
# 7956  https://www.linkedin.com/adrianlievano  name + 2521  786-515-4282
# 4152  https://www.linkedin.com/adrianlievano  name + 1668  786-515-4282
# 4149  https://www.linkedin.com/adrianlievano  name + 4844  786-515-4282
# 4147  https://www.linkedin.com/adrianlievano  name + 7471  786-515-4282
#
#       years_of_experience
# 4999                    5
# 7956                    4
# 4152                    6
# 4149                    2
# 4147                    3

# %% [markdown]
# ## Filter by years experience

# %%
df_candidates[df_candidates['years_of_experience'] >= int(opportunity_sample_request['min_years_experience'])].head()
# Out:
#              city           current_position degree                  email  \
# 4     Los Angeles             Data Scientist    2nd  3034xxxxxxx@gmail.com
# 28    Los Angeles  Machine Learning Engineer    2nd   321xxxxxxx@gmail.com
# 35  New York City  Machine Learning Engineer    1st    30xxxxxxx@gmail.com
# 42    Los Angeles             Data Scientist    2nd  6622xxxxxxx@gmail.com
# 44  San Francisco          Software Engineer    2nd  2948xxxxxxx@gmail.com
#
#    highestLevelOfEducation    id  \
# 4                      phd  8464
# 28                  master  7477
# 35                bachelor  7187
# 42                bachelor  9567
# 44                  master  1559
#
#                                             image_url             industry  \
# 4   https://www.linkedin.com/adrianlievano/profile...           Technology
# 28  https://www.linkedin.com/adrianlievano/profile...              Biotech
# 35  https://www.linkedin.com/adrianlievano/profile...  Enterprise Software
# 42  https://www.linkedin.com/adrianlievano/profile...           Technology
# 44  https://www.linkedin.com/adrianlievano/profile...             Internet
#
#                               linkedin_url         name  phone_number  \
# 4   https://www.linkedin.com/adrianlievano  name + 7636  786-515-4282
# 28  https://www.linkedin.com/adrianlievano  name + 9206  786-515-4282
# 35  https://www.linkedin.com/adrianlievano   name + 449  786-515-4282
# 42  https://www.linkedin.com/adrianlievano   name + 156  786-515-4282
# 44  https://www.linkedin.com/adrianlievano  name + 8893  786-515-4282
#
#     years_of_experience
# 4                     7
# 28                    7
# 35                    7
# 42                    7
# 44                    7

# %% [markdown]
# # Heuristic 1: Knowledge Based Recommendation System

# %%
def heuristic_one(opportunity_request, df_candidates):
    '''Arguments:
            opportunity: a dictionary from a poster seeking candidates
            df_candidates: total pool of 1st and 2nd degree connections from the opportunity poster
            
        OUTPUTS:
        ranked dataframe based on simple heuristic of filters
    '''
    blurb = opportunity_request['blurb']
    highestLevelOfEducation = opportunity_request['highestLevelOfEducation']
    industry = opportunity_request['industry']
    years_exp = opportunity_sample_request['min_years_experience']
    df_candidates['city'] = df_candidates['city']
    #df_candidates['state'] = df_candidates['location'].str[1]
    
    #rank based on blurb relevance score 
    
    #filter based on years experience 
    ranked_df = df_candidates[df_candidates['years_of_experience'] >= int(opportunity_sample_request['min_years_experience'])].head()

    #filter based on location
    ranked_df = ranked_df[(ranked_df['city'] == opportunity_sample_request['city'])]
    
    #filter based on match to degree
   # ranked_df = ranked_df[ranked_df['highestLevelOfEducation'] == str(opportunity_sample_request['highestLevelOfEducation'])].head()
    
    ranked_df = ranked_df.sort_values(by = 'degree', ascending = True).reset_index().drop(['index'], axis = True)
    return ranked_df

# %%
opportunity_sample_request = opportunities_df.iloc[1]

heuristic_one(opportunity_request=opportunity_sample_request, df_candidates=df_candidates)
# Out:
#             city   current_position degree                  email  \
# 0  San Francisco  Software Engineer    2nd  2948xxxxxxx@gmail.com
#
#   highestLevelOfEducation    id  \
# 0                  master  1559
#
#                                            image_url  industry  \
# 0  https://www.linkedin.com/adrianlievano/profile...  Internet
#
#                              linkedin_url         name  phone_number  \
# 0  https://www.linkedin.com/adrianlievano  name + 8893  786-515-4282
#
#    years_of_experience
# 0                    7

# %% [markdown]
# # Heuristic Two: NLP Driven Score Metric for Relevance + No Filters (All Score Based) - Neighborhood Based Collaborative Filtering

# %%
opportunity_sample_request
# Out:
# blurb                      We just need a developer that has six or 7 yea...
# city                                                           San Francisco
# highestLevelOfEducation                                             bachelor
# industry                                                 Enterprise Software
# min_years_experience                                                       7
# title                                              Machine Learning Engineer
# Name: 1, dtype: object

# %% [markdown]
# ### Opportunity title to current position - similarity score

# %%
import gensim 
from gensim.models import Word2Vec

# %%
##helper function to tokenize words
def tokenize(tokens):
    tokens = word_tokenize(opportunity_sample_request['title'])
    stop_words = stopwords.words('english')
    tokens = [word for word in tokens if word not in stop_words]
    cleaned_tokens = []
    lemmatizer = WordNetLemmatizer()

    for tok in tokens:
        cleaned_tokens.append(lemmatizer.lemmatize(tok).lower().strip())

    return cleaned_tokens

# %%
tokens = word_tokenize(opportunity_sample_request['title'])
stop_words = stopwords.words('english')
tokens = [word for word in tokens if word not in stop_words]
cleaned_tokens = []
lemmatizer = WordNetLemmatizer()

for tok in tokens:
    cleaned_tokens.append(lemmatizer.lemmatize(tok).lower().strip())

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', RandomForestClassifier())
])

# %%
## count vectorize & td-idf represents word in a frequency vector. They do not capture syntatical information

# %%
model_job = gensim.models.Word2Vec(cleaned_tokens, min_count = 1,  
                              size = 100, window = 5)

# %% [markdown]
# model_job.similarity('software', 'engineer')

# %% [markdown]
# ### Blurb embeddeding score to text info

# %% [markdown]
# ### Location score function - similarity score

# %% [markdown]
# Distance based similarily score

# %%
def city_point_converter(city):
    if city == opportunity_sample_request['city']:
        return -1
    else:
        return 0
    

df_candidates['city_eucld_score'] = df_candidates['city'].apply(city_point_converter)

# %% [markdown]
# ### Years of Experience Score - similarity score

# %%
df_candidates['years_of_experience_eucld_dist'] = df_candidates['years_of_experience'].apply(lambda x: np.linalg.norm(x-opportunity_sample_request['min_years_experience']))

# %% [markdown]
# ### Euclidean Distance for Education Level

# %%
df_candidates['highestLevelOfEducation_eucld_dist'] = 0

# %%
np.linalg.norm(4-6)/6
# Out:
# 0.3333333333333333

# %%
def educonverter(education_level):
    if education_level == 'high_school':
        return 1
    elif education_level == 'associate':
        return 2
    elif education_level == 'bachelor':
        return 3
    elif education_level == 'master':
        return 4
    elif education_level == 'phd':
        return 5

# %%
df_candidates['edunum'] = df_candidates['highestLevelOfEducation'].apply(educonverter)

# %%
mag_edu = educonverter(opportunity_sample_request['highestLevelOfEducation'])

# %%
df_candidates['highestLevelOfEducation_eucld_dist'] = df_candidates['edunum'].apply(lambda x: np.linalg.norm((x-mag_edu)/mag_edu))

# %% [markdown]
# ### Calculate Total Similarity Score

# %%
df_candidates['eucld_dist'] = df_candidates['highestLevelOfEducation_eucld_dist'] + df_candidates['years_of_experience_eucld_dist'] + df_candidates['city_eucld_score']

# %% [markdown]
# #### Sort by Euclidean Distance - Less means they are closer in similarity

# %%
n_top = 5000
ranked_df = df_candidates.sort_values(by = 'eucld_dist', ascending = True).reset_index().drop(['index', 'edunum'], axis = 1)
ranked_df.iloc[0:n_top].sort_values(by = 'degree', ascending = True)
# Out:
#                city           current_position degree                  email  \
# 3330  New York City                Bioengineer    1st  8345xxxxxxx@gmail.com
# 2897    Los Angeles             Data Scientist    1st  9150xxxxxxx@gmail.com
# 1759    Los Angeles          Software Engineer    1st  7656xxxxxxx@gmail.com
# 3557  New York City                Bioengineer    1st  4617xxxxxxx@gmail.com
# 1761    Los Angeles  Machine Learning Engineer    1st  6346xxxxxxx@gmail.com
# 2894    Los Angeles  Machine Learning Engineer    1st  8010xxxxxxx@gmail.com
# 1763  New York City  Machine Learning Engineer    1st  6328xxxxxxx@gmail.com
# 1764  New York City                Bioengineer    1st    86xxxxxxx@gmail.com
# 1756    Los Angeles             Data Scientist    1st  7083xxxxxxx@gmail.com
# 1765  New York City             Data Scientist    1st  1001xxxxxxx@gmail.com
# 1767  New York City          Software Engineer    1st  7189xxxxxxx@gmail.com
# 1768    Los Angeles  Machine Learning Engineer    1st  5406xxxxxxx@gmail.com
# 1769    Los Angeles             Data Scientist    1st  9894xxxxxxx@gmail.com
# 1770  New York City  Machine Learning Engineer    1st  1406xxxxxxx@gmail.com
# 1771  New York City  Machine Learning Engineer    1st  2424xxxxxxx@gmail.com
# 2164                    5                -1                             2.0
# 2166                    6                 0                             1.0
# 2168                    6                 0                             1.0
# 2169                    6                 0                             1.0
# 2172                    6                 0                             1.0
# 2174                    6                 0                             1.0
# 2175                    6                 0                             1.0
# 2176                    6                 0                             1.0
# 2178                    5                -1                             2.0
# 2179                    5                -1                             2.0
# 2181                    6                 0                             1.0
# 2186                    6                 0                             1.0
# 2187                    6                 0                             1.0
# 2190                    6                 0                             1.0
# 2193                    5                -1                             2.0
# 2194                    5                -1                             2.0
# 2195                    5                -1                             2.0
# 2196                    6                 0                             1.0
# 2197                    5                -1                             2.0
# 2052                    6                 0                             1.0
# 4999                    4                 0                             3.0
#
#       highestLevelOfEducation_eucld_dist  eucld_dist
# 3330                            0.666667    1.666667
# 2897                            0.666667    1.666667
# 1759                            0.666667    0.666667
# 3557                            0.000000    2.000000
# 1761                            0.666667    0.666667
# 2894                            0.666667    1.666667
# 1763                            0.666667    0.666667
# 1764                            0.666667    0.666667
# 1756                            0.666667    0.666667
# 1765                            0.666667    0.666667
# 1767                            0.666667    0.666667
# 1768                            0.666667    0.666667
# 1769                            0.666667    0.666667
# 1770                            0.666667    0.666667
# 1771                            0.666667    0.666667
# 1772                            0.666667    0.666667
# 1773                            0.666667    0.666667
# 1766                            0.666667    0.666667
# 4100                            0.333333    2.333333
# 1755                            0.666667    0.666667
# 2900                            0.666667    1.666667
# 2903                            0.666667    1.666667
# 1737                            0.666667    0.666667
# 1738                            0.666667    0.666667
# 3553                            0.000000    2.000000
# 4114                            0.333333    2.333333
# 3554                            0.000000    2.000000
# 1742                            0.666667    0.666667
# 2898                            0.666667    1.666667
# 1743                            0.666667    0.666667
# ...                                  ...         ...
# 2264                            0.333333    1.333333
# 2240                            0.333333    1.333333
# 2208                            0.000000    1.000000
# 2204                            0.000000    1.000000
# 2200                            0.000000    1.000000
# 2155                            0.000000    1.000000
# 2157                            0.000000    1.000000
# 2161                            0.000000    1.000000
# 2163                            0.000000    1.000000
# 2164                            0.000000    1.000000
# 2166                            0.000000    1.000000
# 2168                            0.000000    1.000000
# 2169                            0.000000    1.000000
# 2172                            0.000000    1.000000
# 2174                            0.000000    1.000000
# 2175                            0.000000    1.000000
# 2176                            0.000000    1.000000
# 2178                            0.000000    1.000000
# 2179                            0.000000    1.000000
# 2181                            0.000000    1.000000
# 2186                            0.000000    1.000000
# 2187                            0.000000    1.000000
# 2190                            0.000000    1.000000
# 2193                            0.000000    1.000000
# 2194                            0.000000    1.000000
# 2195                            0.000000    1.000000
# 2196                            0.000000    1.000000
# 2197                            0.000000    1.000000
# 2052                            0.000000    1.000000
# 4999                            0.000000    3.000000
#
# [5000 rows x 16 columns]

# %% [markdown]
# ### Generate list of candidates

# %%
candidates_total = 10000
emails = []
names = []

for i in range(candidates_total):
    email = ('{}'+'xxxxxxx@gmail.com').format(i)
    emails.append(email)
    
for i in range(candidates_total):
    name = ('name + {}'.format(i))
    names.append(name)

ids = [i for i in range(candidates_total)]
emails = emails
names = names
citys = ['San Francisco', 'New York City', 'Los Angeles']
#state = ['California', 'New York', 'Florida']
current_positions = ['Software Engineer', 'Data Scientist', 'Machine Learning Engineer', 'Bioengineer']
industrys = ['Internet', 'Technology', 'Enterprise Software', 'Biotech']
years_of_experiences = [1, 2, 3, 4, 5, 6, 7]
linkedin_urls = ['https://www.linkedin.com/adrianlievano']
image_urls = ['https://www.linkedin.com/adrianlievano/profile_pic.png']
degrees = ['1st', '2nd']
highestLevelOfEducations = ['high_school', 'associate', 'bachelor', 'master', 'phd']

candidate_rows = []

for i in range(candidates_total):
    row_ele = {
    'id': random.choice(ids),
    'email': random.choice(emails),
    'name': random.choice(names),
    'phone_number': '786-515-4282',
    'city': random.choice(citys),
    #'location': random.choice(locations),
    'current_position': random.choice(current_positions),
    'industry': random.choice(industrys),
    'years_of_experience': random.choice(years_of_experiences),
    'degree': random.choice(degrees),
    'linkedin_url': random.choice(linkedin_urls),
    'image_url': random.choice(image_urls),
    'highestLevelOfEducation': random.choice(highestLevelOfEducations)
    }
    candidate_rows.append(row_ele)

# %%
candidate_rows
# Out:
# [{'city': 'New York City',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '7747xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 2586,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 170',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  {'city': 'Los Angeles',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '2nd',
#   'email': '8108xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 619,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 2698',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  {'city': 'San Francisco',
#   'current_position': 'Bioengineer',
#   'degree': '1st',
#   'email': '6081xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 5325,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 3178',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 3},
#  {'city': 'Los Angeles',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '5717xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 6259,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 2831',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 1},
#  {'city': 'New York City',
#   'current_position': 'Bioengineer',
#   'degree': '1st',
#   'email': '6595xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 5085,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Technology',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 9671',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 4},
#  {'city': 'San Francisco',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '1st',
#   'email': '8840xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 8208,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 5128',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 3},
#  {'city': 'San Francisco',
#   'current_position': 'Bioengineer',
#   'degree': '2nd',
#   'email': '2974xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 2545,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 

#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 7744',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 3},
#  {'city': 'New York City',
#   'current_position': 'Software Engineer',
#   'degree': '1st',
#   'email': '5100xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'phd',
#   'id': 1578,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 6532',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 7},
#  {'city': 'Los Angeles',
#   'current_position': 'Data Scientist',
#   'degree': '1st',
#   'email': '7227xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 7657,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 7211',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  {'city': 'Los Angeles',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '4863xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 8376,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 8992',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 5},
#  {'city': 'San Francisco',
#   'current_position': 'Data Scientist',
#   'degree': '1st',
#   'email': '5963xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'high_school',
#   'id': 3786,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 4171',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 5},
#  {'city': 'Los Angeles',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '1st',
#   'email': '5257xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 6363,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 7780',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 4},
#  {'city': 'New York City',
#   'current_position': 'Bioengineer',
#   'degree': '2nd',
#   'email': '5593xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 6302,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Technology',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 1985',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 4},
#  {'city': 'San Francisco',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '8479xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 941,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 3900',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  {'city': 'Los Angeles',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '3922xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 2946,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 5310',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 5},
#  {'city': 'San Francisco',
#   'current_position': 'Bioengineer',
#   'degree': '1st',
#   'email': '5455xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 7475,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 9574',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  {'city': 'San Francisco',
#   'current_position': 'Data Scientist',
#   'degree': '1st',
#   'email': '28xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 5608,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 6574',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  {'city': 'New York City',
#   'current_position': 'Data Scientist',
#   'degree': '2nd',
#   'email': '4412xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 7507,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Technology',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 1247',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 1},
#  {'city': 'New York City',
#   'current_position': 'Bioengineer',
#   'degree': '1st',
#   'email': '6512xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'high_school',
#   'id': 2506,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 7562',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  {'city': 'San Francisco',
#   'current_position': 'Data Scientist',
#   'degree': '2nd',
#   'email': '1749xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 3688,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Technology',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 8116',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 3},
#  {'city': 'Los Angeles',
#   'current_position': 'Software Engineer',
#   'degree': '1st',
#   'email': '7793xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 8948,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 3286',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 1},
#  {'city': 'New York City',
#   'current_position': 'Bioengineer',
#   'degree': '2nd',
#   'email': '2431xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'phd',
#   'id': 8905,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 258',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  {'city': 'San Francisco',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '2nd',
#   'email': '4757xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 2411,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 4200',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  {'city': 'San Francisco',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '9296xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 1272,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 2303',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  {'city': 'New York City',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '2nd',
#   'email': '9048xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 398,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 4843',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 7},
#  {'city': 'San Francisco',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '2nd',
#   'email': '7046xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'associate',
#   'id': 1738,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Biotech',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 4281',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 3},
#  {'city': 'San Francisco',
#   'current_position': 'Bioengineer',
#   'degree': '2nd',
#   'email': '2953xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 2880,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 4958',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 7},
#  {'city': 'Los Angeles',
#   'current_position': 'Machine Learning Engineer',
#   'degree': '2nd',
#   'email': '6708xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'phd',
#   'id': 9292,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Internet',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 3650',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 5},
#  {'city': 'San Francisco',
#   'current_position': 'Bioengineer',
#   'degree': '2nd',
#   'email': '765xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'master',
#   'id': 6600,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 3948',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 2},
#  ...]

# %%
candidate_rows[0]
# Out:
# {'city': 'New York City',
#  'current_position': 'Software Engineer',
#  'degree': '2nd',
#  'email': '7747xxxxxxx@gmail.com',
#  'highestLevelOfEducation': 'bachelor',
#  'id': 2586,
#  'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#  'industry': 'Enterprise Software',
#  'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#  'name': 'name + 170',
#  'phone_number': '786-515-4282',
#  'years_of_experience': 6}

# %%
opportunity_sample_request
# Out:
# blurb                      We just need a developer that has six or 7 yea...
# city                                                           San Francisco
# highestLevelOfEducation                                             bachelor
# industry                                                 Enterprise Software
# min_years_experience                                                       7
# title                                              Machine Learning Engineer
# Name: 1, dtype: object

# %%
def city_point_converter(city):
    if city == opportunity_sample_request['city']:
        return -1
    else:
        return 0

def educonverter(education_level):
    if education_level == 'high_school':
        return 1
    elif education_level == 'associate':
        return 2
    elif education_level == 'bachelor':
        return 3
    elif education_level == 'master':
        return 4
    elif education_level == 'phd':
        return 5

# %%
sample_candidate = [candidate_rows[0]]
sample_candidate
# Out:
# [{'city': 'New York City',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '7747xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 2586,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 170',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6}]

# %%
df = pd.DataFrame(sample_candidate)
df['city']
# Out:
# 0    New York City
# Name: city, dtype: object

# %% [markdown]
# pd.DataFrame.from_dict(sample_candidate)
# pd.DataFrame(list(sample_candidate.items()), columns=['id', 'email', 'name', 'phone_number', 'city',
#                                                      'current_position', 'industry', 'years_of_experience',
#                                                      'degree', 'linkedin_url', 'image_url', 'highestLevelOfEducation'], typ='series')

# %%
def heuristic_two(candidate, opp_request, n_top = 50): 
    '''Arguments:
            candidate: list of User info
            opp_request: a dictionary from a poster seeking candidates

       Returns:
        ranked dataframe of users and similarity score sorted by degree connection
    '''
    
    candidates_list = candidate
    df_candidates = pd.DataFrame(candidates_list)
    
    def city_point_converter(city):
        if city == opportunity_request['city']:
            return -1
        else:
            return 0
    
    #Calculate Location Similarity Score 
   
    #df_candidates['city_eucld_score'] = df_candidates['city'].apply(city_point_converter)
    df_candidates['city_eucld_score'] = 0
    
    #Calculate Years of Experience Similarity Score
    df_candidates['years_of_experience_eucld_dist'] = df_candidates['years_of_experience'].apply(lambda x: np.linalg.norm(x-opp_request['min_years_experience']))

    #Calculate Level of Education Similarity Score
    df_candidates['edunum'] = df_candidates['highestLevelOfEducation'].apply(educonverter)
    df_candidates['highestLevelOfEducation_eucld_dist'] = df_candidates['edunum'].apply(lambda x: np.linalg.norm(x-educonverter(opp_request['highestLevelOfEducation'])))
    
    #Calculate Total Similarity Score
    df_candidates['eucld_dist'] = df_candidates['highestLevelOfEducation_eucld_dist'] + df_candidates['years_of_experience_eucld_dist'] + df_candidates['city_eucld_score']
    
    print(opp_request)
    print('')
    
    df_candidates = df_candidates.sort_values(by = ['eucld_dist', 'degree'], ascending = True).reset_index().drop(['index', 'edunum'], axis = 1)
    tupp = (candidate[0], df_candidates['eucld_dist'][0])
    return tupp

# %%
opportunity_sample_request
# Out:
# blurb                      We just need a developer that has six or 7 yea...
# city                                                           San Francisco
# highestLevelOfEducation                                             bachelor
# industry                                                 Enterprise Software
# min_years_experience                                                       7
# title                                              Machine Learning Engineer
# Name: 1, dtype: object

# %%
heuristic_two(sample_candidate, opportunity_sample_request)
# Out:
# blurb                      We just need a developer that has six or 7 yea...
# city                                                           San Francisco
# highestLevelOfEducation                                             bachelor
# industry                                                 Enterprise Software
# min_years_experience                                                       7
# title                                              Machine Learning Engineer
# Name: 1, dtype: object
# ({'city': 'New York City',
#   'current_position': 'Software Engineer',
#   'degree': '2nd',
#   'email': '7747xxxxxxx@gmail.com',
#   'highestLevelOfEducation': 'bachelor',
#   'id': 2586,
#   'image_url': 'https://www.linkedin.com/adrianlievano/profile_pic.png',
#   'industry': 'Enterprise Software',
#   'linkedin_url': 'https://www.linkedin.com/adrianlievano',
#   'name': 'name + 170',
#   'phone_number': '786-515-4282',
#   'years_of_experience': 6},
#  1.0)
