# %%
import random

import pandas as pd
import nltk
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report
from sklearn.externals import joblib
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adrianlievano/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Explore the input data

# %%
opportunity = {
    'industry': 'Internet',
    'min_years_experience': 3,
    'location': ['San Francisco', 'CA'],
    'degrees': 'Computer Science',
    'blurb': 'I need a software engineer that has experience in pytorch, python, aws, spark, and airflow. They should want to work for a startup that has less than 500 employees. We do not want new graduates.',
    'title': 'Seeking Software Engineer (Full-Time)'
}

# %%
industrys = ['Internet', 'Technology', 'Enterprise Software']
min_years_experiences = [1, 2, 3, 4, 5, 6, 7]
locations = [['San Francisco', 'CA'], ['New York City', 'NY'], ['Los Angeles', 'CA']]
degrees = ['Engineering', 'Math', 'Economics']
blurbs = ['I need a software engineer that has experience in pytorch, python, aws, spark, and airflow. They should want to work for a startup that has less than 500 employees. We do not want new graduates.',
          'We need a full stack machine learning engineer that knows REST APIs, flask, and tensorflow.',
          'Find me data scientist that knows SQL, tableu, excel, machine learning.', 
          'We just need a developer that has six or 7 years of experience']
titles = ['Software Engineer', 'Data Scientist', 'Machine Learning Engineer', 'Software Engineer (Machine Learning)']

df_test = pd.DataFrame()

num_opportunities = 5
rows = []

for i in range(num_opportunities):
    row_ele = {
    'industry': random.choice(industrys),
    'min_years_experience': random.choice(min_years_experiences),
    'location': random.choice(locations),
    'degrees': random.choice(degrees),
    'blurb': random.choice(blurbs),
    'title': random.choice(titles)
    }
    rows.append(row_ele)

# %% [markdown]
# ## Construct Dummy Table - Opportunity Submission Table
#
# #### This is a table with queries that a poster might use to find a candidate in their network

# %%
opportunities_df = pd.DataFrame(rows)
opportunities_df.head(10)
# Out:
#                                                blurb      degrees  \
# 0  I need a software engineer that has experience...    Economics
# 1  We need a full stack machine learning engineer...    Economics
# 2  Find me data scientist that knows SQL, tableu,...         Math
# 3  We need a full stack machine learning engineer...  Engineering
# 4  We just need a developer that has six or 7 yea...         Math
#
#               industry             location  min_years_experience  \
# 0  Enterprise Software  [New York City, NY]                     7
# 1           Technology  [San Francisco, CA]                     4
# 2             Internet    [Los Angeles, CA]                     2
# 3             Internet  [San Francisco, CA]                     4
# 4  Enterprise Software  [New York City, NY]                     2
#
#                                   title
# 0             Machine Learning Engineer
# 1                     Software Engineer
# 2                     Software Engineer
# 3                     Software Engineer
# 4  Software Engineer (Machine Learning)

# %% [markdown]
# ## Construct Dummy Table - Candidate Table

# %% [markdown]
# Candidate dictionary
# {
#     id: int
#     email: 'str'
#     name: 'str'
#     location: list['city', 'state']
#     current_position: 'str',
#     years_of_experience: int
#     industry: 'str'
#     degree_connection: str
#     degree = str
# }

# %%
candidates_total = 10000
emails = []
names = []

for i in range(candidates_total):
    email = ('{}'+'xxxxxxx@gmail.com').format(i)
    emails.append(email)
    
for i in range(candidates_total):
    name = ('name + {}'.format(i))
    names.append(name)

# %%
ids = [i for i in range(candidates_total)]
emails = emails
names = names
locations = [['San Francisco', 'CA'], ['New York City', 'NY'], ['Los Angeles', 'CA'], ['Miami', 'FL']]
current_positions = ['Software Engineer', 'Data Scientist', 'Machine Learning Engineer', 'Bioengineer']
years_of_experiences = [1, 2, 3, 4, 5, 6, 7]
industrys = ['Internet', 'Technology', 'Enterprise Software', 'Biotech']
degree_connections = ['1st', '2nd']
degrees = ['Engineering', 'Math', 'Economics', 'Biology', 'Chemistry', 'English']


candidate_rows = []

for i in range(candidates_total):
    row_ele = {
    'id': random.choice(ids),
    'email': random.choice(emails),
    'name': random.choice(names),
    'location': random.choice(locations),
    'current_position': random.choice(current_positions),
    'years_of_experience': random.choice(years_of_experiences),
    'industry': random.choice(industrys),
    'degree_connection': random.choice(degree_connections),
    'degree': random.choice(degrees)
    }
    candidate_rows.append(row_ele)

# %%
df_candidates = pd.DataFrame(candidate_rows)
df_candidates
# Out:
#                current_position       degree degree_connection  \
# 0     Machine Learning Engineer         Math               2nd
# 1                   Bioengineer         Math               2nd
# 2                   Bioengineer    Chemistry               1st
# 3     Machine Learning Engineer    Economics               1st
# 4                Data Scientist    Economics               1st
# 5     Machine Learning Engineer    Economics               2nd
# 6                   Bioengineer    Economics               2nd
# 7             Software Engineer  Engineering               2nd
# 8                   Bioengineer    Chemistry               2nd
# 9                   Bioengineer         Math               1st
# 10    Machine Learning Engineer      English               1st
# 11               Data Scientist    Economics               1st
# 12            Software Engineer  Engineering               1st
# 13            Software Engineer      English               2nd
# 14               Data Scientist    Economics               2nd
# 15               Data Scientist    Chemistry               1st
# 16    Machine Learning Engineer    Chemistry               1st
# 17                  Bioengineer      English               1st
# 18                  Bioengineer  Engineering               1st
# 19                  Bioengineer         Math               2nd
# 20            Software Engineer    Economics               1st
# 21            Software Engineer  Engineering               2nd
# 22            Software Engineer      Biology               1st
# 23            Software Engineer  Engineering               2nd
# 24                  Bioengineer      English               2nd
# 25            Software Engineer  Engineering               1st
# 26    Machine Learning Engineer    Chemistry               2nd
# 27            Software Engineer         Math               2nd
# 28    Machine Learning Engineer      Biology               1st
# 29            Software Engineer    Chemistry               1st
# ...                         ...          ...               ...
# 9970          Software Engineer      Biology               2nd
# 9971                Bioengineer    Chemistry               1st
# 9972                Bioengineer      English               2nd
# 9973  Machine Learning Engineer         Math               2nd
# 9974          Software Engineer      Biology               2nd
# 9975          Software Engineer    Economics               1st
# 9976          Software Engineer    Chemistry               2nd
# 9977  Machine Learning Engineer    Economics               1st
# 9978                Bioengineer    Chemistry               1st
# 9979             Data Scientist    Economics               2nd
# 9980                Bioengineer      English               1st
# 9981                Bioengineer    Economics               1st
# 9982  Machine Learning Engineer         Math               1st
# 9983          Software Engineer      English               1st
# 9984          Software Engineer    Economics               2nd
# 9985  Machine Learning Engineer    Economics               1st
# 9986             Data Scientist      English               1st
# 9987  Machine Learning Engineer         Math               2nd
# 9988                Bioengineer  Engineering               1st
# 9989                Bioengineer      Biology               2nd
# 9990  Machine Learning Engineer  Engineering               1st
# 9991  Machine Learning Engineer    Economics               2nd
# 9992                Bioengineer      English               2nd
# 9993  Machine Learning Engineer  Engineering               2nd
# 9994                Bioengineer    Economics               2nd
# 9995  Machine Learning Engineer  Engineering               1st
# 9996          Software Engineer    Chemistry               1st
# 9997             Data Scientist    Chemistry               1st
# 9998                Bioengineer    Chemistry               1st
# 9999          Software Engineer      Biology               2nd
#
#                       email    id             industry             location  \
# 0     6210xxxxxxx@gmail.com  9289              Biotech          [Miami, FL]
# 1     5940xxxxxxx@gmail.com  1393              Biotech          [Miami, FL]
# 2     9503xxxxxxx@gmail.com  5473  Enterprise Software          [Miami, FL]
# 3     6964xxxxxxx@gmail.com  8539              Biotech  [New York City, NY]
# 4     7550xxxxxxx@gmail.com  1712             Internet  [San Francisco, CA]
# 5     3694xxxxxxx@gmail.com  7862           Technology    [Los Angeles, CA]
# 6     4674xxxxxxx@gmail.com  2618             Internet  [New York City, NY]
# 7     1712xxxxxxx@gmail.com  1191  Enterprise Software    [Los Angeles, CA]
# 8     4423xxxxxxx@gmail.com  3918           Technology          [Miami, FL]
# 9     3727xxxxxxx@gmail.com  5150           Technology  [San Francisco, CA]
# 10    7322xxxxxxx@gmail.com  4649           Technology          [Miami, FL]
# 11    7300xxxxxxx@gmail.com  7369             Internet  [New York City, NY]
# 12    3015xxxxxxx@gmail.com  3815             Internet    [Los Angeles, CA]
# 13    2573xxxxxxx@gmail.com  4961             Internet          [Miami, FL]
# 14    6264xxxxxxx@gmail.com  5429           Technology  [New York City, NY]
# 15    9596xxxxxxx@gmail.com  9162              Biotech          [Miami, FL]
# 16    6330xxxxxxx@gmail.com  8316           Technology  [San Francisco, CA]
# 17    1188xxxxxxx@gmail.com  3448              Biotech  [San Francisco, CA]
# 18    2630xxxxxxx@gmail.com  6950             Internet          [Miami, FL]
# 19    7063xxxxxxx@gmail.com  3014           Technology    [Los Angeles, CA]
# 20    4195xxxxxxx@gmail.com  2339           Technology  [New York City, NY]
# 21     847xxxxxxx@gmail.com  4440  Enterprise Software    [Los Angeles, CA]
# 22    2101xxxxxxx@gmail.com  5528              Biotech    [Los Angeles, CA]
# 23    9112xxxxxxx@gmail.com  4516  Enterprise Software    [Los Angeles, CA]
# 24     867xxxxxxx@gmail.com  7378              Biotech  [San Francisco, CA]
# 25    6601xxxxxxx@gmail.com  2333             Internet  [San Francisco, CA]
# 26    7371xxxxxxx@gmail.com  9906           Technology  [San Francisco, CA]
# 27    6108xxxxxxx@gmail.com   888              Biotech  [New York City, NY]
# 28    5683xxxxxxx@gmail.com  6728  Enterprise Software          [Miami, FL]
# 29    3948xxxxxxx@gmail.com    15           Technology  [San Francisco, CA]
# ...                     ...   ...                  ...                  ...
# 9970   475xxxxxxx@gmail.com  2346           Technology  [San Francisco, CA]
# 9971  5625xxxxxxx@gmail.com  3567           Technology  [New York City, NY]
# 9972  1953xxxxxxx@gmail.com  1034  Enterprise Software    [Los Angeles, CA]
# 9973  8771xxxxxxx@gmail.com   333              Biotech          [Miami, FL]
# 9974  3332xxxxxxx@gmail.com  2233              Biotech  [San Francisco, CA]
# 9975  4861xxxxxxx@gmail.com  6102  Enterprise Software  [San Francisco, CA]
# 9976   161xxxxxxx@gmail.com  7809              Biotech  [New York City, NY]
# 9977  4859xxxxxxx@gmail.com  7309           Technology          [Miami, FL]
# 9978  6088xxxxxxx@gmail.com  4324              Biotech    [Los Angeles, CA]
# 9979  1561xxxxxxx@gmail.com   914           Technology  [San Francisco, CA]
# 9980  6464xxxxxxx@gmail.com  6846             Internet    [Los Angeles, CA]
# 9981  4591xxxxxxx@gmail.com  2307              Biotech          [Miami, FL]
# 9982  3745xxxxxxx@gmail.com  2428  Enterprise Software  [San Francisco, CA]
# 9983  6334xxxxxxx@gmail.com  4878              Biotech          [Miami, FL]
# 9984  1169xxxxxxx@gmail.com  6829           Technology  [New York City, NY]
# 9985  4902xxxxxxx@gmail.com  8808           Technology  [San Francisco, CA]
# 9986  6636xxxxxxx@gmail.com   805             Internet  [New York City, NY]
# 9987   857xxxxxxx@gmail.com  9903              Biotech  [San Francisco, CA]
# 9988   606xxxxxxx@gmail.com  5704             Internet    [Los Angeles, CA]
# 9989  6716xxxxxxx@gmail.com  6584  Enterprise Software          [Miami, FL]
# 9990  2688xxxxxxx@gmail.com   113           Technology  [San Francisco, CA]
# 9991  8977xxxxxxx@gmail.com  2504              Biotech    [Los Angeles, CA]
# 9992   338xxxxxxx@gmail.com  9606             Internet          [Miami, FL]
# 9993  9290xxxxxxx@gmail.com  8296              Biotech  [New York City, NY]
# 9994  4695xxxxxxx@gmail.com  1605  Enterprise Software    [Los Angeles, CA]
# 9995  4805xxxxxxx@gmail.com    99              Biotech  [New York City, NY]
# 9996  8891xxxxxxx@gmail.com  8607              Biotech    [Los Angeles, CA]
# 9997  3527xxxxxxx@gmail.com  8518           Technology  [San Francisco, CA]
# 9998  7487xxxxxxx@gmail.com  4386              Biotech  [San Francisco, CA]
# 9999  7532xxxxxxx@gmail.com   198             Internet  [San Francisco, CA]
#
#              name  years_of_experience
# 0      name + 792                    2
# 1     name + 8998                    6
# 2     name + 7114                    5
# 3     name + 8009                    5
# 4     name + 6795                    4
# 5      name + 538                    6
# 6     name + 6798                    5
# 7      name + 876                    4
# 8       name + 96                    6
# 9     name + 8956                    6
# 10    name + 3188                    6
# 11    name + 2125                    5
# 12    name + 2172                    3
# 13    name + 3767                    3
# 14    name + 7797                    7
# 15     name + 412                    1
# 16    name + 7460                    7
# 17    name + 6326                    5
# 18    name + 2091                    3
# 19    name + 3656                    6
# 20    name + 6473                    5
# 21    name + 9385                    4
# 22    name + 8181                    6
# 23    name + 6819                    6
# 24    name + 6115                    3
# 25    name + 1730                    1
# 26    name + 2725                    3
# 27    name + 4758                    7
# 28    name + 5849                    1
# 29    name + 3646                    5
# ...           ...                  ...
# 9970  name + 7512                    6
# 9971  name + 5919                    7
# 9972  name + 1053                    2
# 9973  name + 9180                    3
# 9974  name + 2470                    2
# 9975  name + 7666                    5
# 9976  name + 8190                    2
# 9977  name + 7740                    4
# 9978  name + 1590                    2
# 9979  name + 2642                    4
# 9980  name + 8808                    2
# 9981  name + 5567                    3
# 9982  name + 1889                    4
# 9983  name + 6330                    4
# 9984  name + 9622                    5
# 9985  name + 3729                    5
# 9986  name + 4197                    3
# 9987  name + 8965                    4
# 9988  name + 8060                    1
# 9989  name + 6708                    6
# 9990  name + 2963                    5
# 9991  name + 2037                    4
# 9992  name + 9686                    3
# 9993  name + 6021                    2
# 9994  name + 7526                    4
# 9995  name + 2182                    1
# 9996  name + 9336                    6
# 9997  name + 5271                    6
# 9998  name + 6636                    3
# 9999  name + 8955                    6
#
# [10000 rows x 9 columns]

# %% [markdown]
# ### Phase 1: Knowledge Based Heuristic ###

# %% [markdown]
# 1. Filter 1: Filter by location
# 2. Filter 2: Filter by >= years of experience
# 3. Filter 3: Filter subset by title embeddings
# 4. Filter 4: Filter by degrees
# 5. Filter 5: Filter by industry
# 6. Filter 6: Filter by blurb
#
# Create score column in candidate table that assigns reward for each applicable filter

# %%
opportunity_sample_request = opportunities_df.iloc[0]
opportunity_sample_request.head() #pandas series
# Out:
# blurb                   I need a software engineer that has experience...
# degrees                                                         Economics
# industry                                              Enterprise Software
# location                                              [New York City, NY]
# min_years_experience                                                    7
# Name: 0, dtype: object

# %%
opportunity_sample_request['location']
# Out:
# ['New York City', 'NY']

# %%
opportunity_sample_request['min_years_experience']
# Out:
# 7

# %%
(opportunity_sample_request['location'])
# Out:
# ['New York City', 'NY']

# %% [markdown]
# ## Filter based on location

# %%
df_candidates[df_candidates['location'] == list(opportunity_sample_request['location'])].head()

# %% [markdown]
# ## Filter based on current_position - (TBD)

# %% [markdown]
# opportunity_sample_request['current_position']

# %% [markdown]
# df_candidates[df_candidates['current_position'] == str(opportunity_sample_request['current_position'])].head()

# %% [markdown]
# ## Filter based on Degree

# %% [markdown]
# ## Filter based on degree major

# %%
df_candidates[df_candidates['degree'] == str(opportunity_sample_request['degrees'])].head()
# Out:
#              current_position     degree degree_connection  \
# 3   Machine Learning Engineer  Economics               1st
# 4              Data Scientist  Economics               1st
# 5   Machine Learning Engineer  Economics               2nd
# 6                 Bioengineer  Economics               2nd
# 11             Data Scientist  Economics               1st
#
#                     email    id    industry             location         name  \
# 3   6964xxxxxxx@gmail.com  8539     Biotech  [New York City, NY]  name + 8009
# 4   7550xxxxxxx@gmail.com  1712    Internet  [San Francisco, CA]  name + 6795
# 5   3694xxxxxxx@gmail.com  7862  Technology    [Los Angeles, CA]   name + 538
# 6   4674xxxxxxx@gmail.com  2618    Internet  [New York City, NY]  name + 6798
# 11  7300xxxxxxx@gmail.com  7369    Internet  [New York City, NY]  name + 2125
#
#     years_of_experience
# 3                     5
# 4                     4
# 5                     6
# 6                     5
# 11                    5

# %% [markdown]
# ## Sort by degree connection

# %%
df_candidates.sort_values(by = 'degree_connection', ascending = True).head()
# Out:
#                current_position       degree degree_connection  \
# 8347             Data Scientist  Engineering               1st
# 8245  Machine Learning Engineer      English               1st
# 8246             Data Scientist    Economics               1st
# 3533             Data Scientist    Economics               1st
# 3532                Bioengineer    Economics               1st
#
#                       email    id  industry             location         name  \
# 8347  1406xxxxxxx@gmail.com  7900  Internet    [Los Angeles, CA]   name + 736
# 8245  2663xxxxxxx@gmail.com   354  Internet  [San Francisco, CA]   name + 791
# 8246   281xxxxxxx@gmail.com  7978  Internet          [Miami, FL]  name + 5033
# 3533  4877xxxxxxx@gmail.com  6443   Biotech          [Miami, FL]  name + 8377
# 3532  3793xxxxxxx@gmail.com  2383   Biotech  [New York City, NY]  name + 2939
#
#       years_of_experience
# 8347                    4
# 8245                    1
# 8246                    2
# 3533                    2
# 3532                    1

# %% [markdown]
# ## Filter by years experience

# %%
df_candidates[df_candidates['years_of_experience'] >= int(opportunity_sample_request['min_years_experience'])].head()
# Out:
#              current_position       degree degree_connection  \
# 14             Data Scientist    Economics               2nd
# 16  Machine Learning Engineer    Chemistry               1st
# 27          Software Engineer         Math               2nd
# 36                Bioengineer  Engineering               1st
# 38             Data Scientist  Engineering               2nd
#
#                     email    id    industry             location         name  \
# 14  6264xxxxxxx@gmail.com  5429  Technology  [New York City, NY]  name + 7797
# 16  6330xxxxxxx@gmail.com  8316  Technology  [San Francisco, CA]  name + 7460
# 27  6108xxxxxxx@gmail.com   888     Biotech  [New York City, NY]  name + 4758
# 36  8547xxxxxxx@gmail.com   716     Biotech          [Miami, FL]  name + 5187
# 38  2467xxxxxxx@gmail.com  5221     Biotech  [New York City, NY]  name + 6410
#
#     years_of_experience
# 14                    7
# 16                    7
# 27                    7
# 36                    7
# 38                    7

# %% [markdown]
# ## Come up with Relevance Score when user makes a query for less clear categories
#
# filter location
# score = score_location + score

# %%
def heuristic_one(opportunity_request, df_candidates):
    '''Arguments:
            opportunity: a dictionary from a poster seeking candidates
            df_candidates: total pool of 1st and 2nd degree connections from the opportunity poster
            
        OUTPUTS:
        ranked dataframe based on simple heuristic of filters
    '''
    blurb = opportunity_request['blurb']
    degrees = opportunity_request['degrees']
    industry = opportunity_request['industry']
    years_exp = opportunity_sample_request['min_years_experience']
    
    
    #rank based on blurb relevance score 
    
    #filter based on years experience 
    ranked_df = df_candidates[df_candidates['years_of_experience'] >= int(opportunity_sample_request['min_years_experience'])].head()

    #filter based on location
    #ranked_df
    
    #filter based on match to degree
    ranked_df = ranked_df[ranked_df['degree'] == str(opportunity_sample_request['degrees'])].head()
    
    ranked_df = ranked_df.sort_values(by = 'degree_connection', ascending = True).reset_index().drop(['index'], axis = True)
    return ranked_df

# %%
opportunity_sample_request = opportunities_df.iloc[1]
opportunity_sample_request
# Out:
# blurb                   We need a full stack machine learning engineer...
# degrees                                                         Economics
# industry                                                       Technology
# location                                              [San Francisco, CA]
# min_years_experience                                                    4
# title                                                   Software Engineer
# Name: 1, dtype: object

# %%
opportunity_sample_request = opportunities_df.iloc[1]
heuristic_one(opportunity_request=opportunity_sample_request, df_candidates=df_candidates)
# Out:
#             current_position     degree degree_connection  \
# 0  Machine Learning Engineer  Economics               1st
# 1             Data Scientist  Economics               1st
# 2  Machine Learning Engineer  Economics               2nd
#
#                    email    id    industry             location         name  \
# 0  6964xxxxxxx@gmail.com  8539     Biotech  [New York City, NY]  name + 8009
# 1  7550xxxxxxx@gmail.com  1712    Internet  [San Francisco, CA]  name + 6795
# 2  3694xxxxxxx@gmail.com  7862  Technology    [Los Angeles, CA]   name + 538
#
#    years_of_experience
# 0                    5
# 1                    4
# 2                    6

# %% [markdown]
# # Heuristic Two: NLP Driven Score Metric for Relevance

# %%
def heuristic_two(df): 
    '''Arguments:
            opportunity: a dictionary from a poster seeking candidates
            df_candidates: total pool of 1st and 2nd degree connections from the opportunity poster
    '''
    pass

# %% [markdown]
# # Heuristic Three: MORE NLP Driven Score Metric for Relevance

# %%
def heuristic_three(df):
    '''Arguments:
            opportunity: a dictionary from a poster seeking candidates
            df_candidates: total pool of 1st and 2nd degree connections from the opportunity poster
    '''
    pass
